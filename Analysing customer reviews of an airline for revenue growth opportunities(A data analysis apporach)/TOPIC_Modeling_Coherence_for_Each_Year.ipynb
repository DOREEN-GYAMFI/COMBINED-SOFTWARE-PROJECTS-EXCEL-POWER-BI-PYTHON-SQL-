# %% [markdown]
# What is coherence?
#
# Coherence is a measure of how well the words in a topic relate to each other. It reflects the human intuition of what makes a good topic. A high coherence score means that the topic is consistent, clear, and relevant. A low coherence score means that the topic is vague, noisy, or irrelevant.

# %% [markdown]
# # **Loading Libraries**

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import random
import numpy as np
import pandas as pd
import gensim
import gensim.corpora as corpora
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.phrases import Phrases, Phraser
from pprint import pprint
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# %%
# Load your DataFrame from the CSV file
df = pd.read_csv('/content/all_reviews_with_sentiments(2018-2022).csv')

# %% [markdown]
# # Checking coherence for number of topics to use
# so I check for each year,the number of topic that has a high coherence for every year then I use that for every year.

# %% [markdown]
# # all 5 years

# %%
# Convert float values to strings
df['Review'] = df['Review'].astype(str)

# Tokenize documents
documents = [comment.split() for comment in df["Review"]]

# Create dictionary and corpus
vocab = corpora.Dictionary(documents)
corpus = [vocab.doc2bow(text) for text in documents]

# Set hyperparameters
alpha = 0.1  # Hyperparameter for document-topic distribution
eta = 0.01    # Hyperparameter for topic-word distribution, determined automatically by Gensim

# Define a range of topic numbers to explore
topic_range = range(5, 31)

def compute_coherence(documents, vocab, corpus, topic_range):
    coherence_scores = []
    for num_topics in topic_range:
        lda = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                              id2word=vocab,
                                              num_topics=num_topics,
                                              alpha=alpha,
                                              eta=eta,
                                              random_state=42)  # Choose any desired seed value

        coherence_model = CoherenceModel(model=lda, texts=documents, dictionary=vocab, coherence='c_v')
        coherence = coherence_model.get_coherence()
        coherence_scores.append(coherence)

    return coherence_scores
# Call the function and store the results
coherence_scores = compute_coherence(documents, vocab, corpus, topic_range)

# Plotting coherence scores
plt.figure(figsize=(10, 5))
plt.plot(topic_range, coherence_scores, marker='o')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score")
plt.title("Coherence Score vs. Number of Topics(5-year Period)")

# Set the x-axis ticks explicitly to show all numbers
plt.xticks(list(topic_range))

plt.show()

# %% [markdown]
# ## 2018

# %%
# Filter rows where the 'Year' column is equal to 2018
df1_2018 = df[df['Year'] == 2018]

# Convert float values to strings
df1_2018['Review'] = df1_2018['Review'].astype(str)

# Tokenize documents
documents = [comment.split() for comment in df1_2018["Review"]]

# Create dictionary and corpus
vocab = corpora.Dictionary(documents)
corpus = [vocab.doc2bow(text) for text in documents]

# Set hyperparameters
alpha = 0.1  # Hyperparameter for document-topic distribution
eta = 0.01    # Hyperparameter for topic-word distribution, determined automatically by Gensim

# Define a range of topic numbers to explore
topic_range = range(5, 31)

def compute_coherence(documents, vocab, corpus, topic_range):
    coherence_scores = []
    for num_topics in topic_range:
        lda = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                              id2word=vocab,
                                              num_topics=num_topics,
                                              alpha=alpha,
                                              eta=eta,
                                              random_state=42)  # Choose any desired seed value

        coherence_model = CoherenceModel(model=lda, texts=documents, dictionary=vocab, coherence='c_v')
        coherence = coherence_model.get_coherence()
        coherence_scores.append(coherence)

    return coherence_scores

# Call the function and store the results
coherence_scores = compute_coherence(documents, vocab, corpus, topic_range)

# Plotting coherence scores
plt.figure(figsize=(10, 5))
plt.plot(topic_range, coherence_scores, marker='o')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score")
plt.title("Coherence Score vs. Number of Topics(2018)")

# Set the x-axis ticks explicitly to show all numbers
plt.xticks(list(topic_range))

plt.show()
# Out:
# <ipython-input-5-ffe14cdb1e73>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2018['Review'] = df1_2018['Review'].astype(str)
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# ...

# %% [markdown]
# ## 2019

# %%
# Filter rows where the 'Year' column is equal to 2019
df1_2019 = df[df['Year'] == 2019]

# Convert float values to strings
df1_2019['Review'] = df1_2019['Review'].astype(str)

# Tokenize documents
documents = [comment.split() for comment in df1_2019["Review"]]

# Create dictionary and corpus
vocab = corpora.Dictionary(documents)
corpus = [vocab.doc2bow(text) for text in documents]

# Set hyperparameters
alpha = 0.1  # Hyperparameter for document-topic distribution
eta = 0.01    # Hyperparameter for topic-word distribution, determined automatically by Gensim

# Define a range of topic numbers to explore
topic_range = range(5, 31)

def compute_coherence(documents, vocab, corpus, topic_range):
    coherence_scores = []
    for num_topics in topic_range:
        lda = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                              id2word=vocab,
                                              num_topics=num_topics,
                                              alpha=alpha,
                                              eta=eta,
                                              random_state=42)  # Choose any desired seed value

        coherence_model = CoherenceModel(model=lda, texts=documents, dictionary=vocab, coherence='c_v')
        coherence = coherence_model.get_coherence()
        coherence_scores.append(coherence)

    return coherence_scores

# Call the function and store the results
coherence_scores = compute_coherence(documents, vocab, corpus, topic_range)

# Plotting coherence scores
plt.figure(figsize=(10, 5))
plt.plot(topic_range, coherence_scores, marker='o')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score")
plt.title("Coherence Score vs. Number of Topics (2019)")

# Set the x-axis ticks explicitly to show all numbers
plt.xticks(list(topic_range))

plt.show()
# Out:
# <ipython-input-6-137d27267ecc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2019['Review'] = df1_2019['Review'].astype(str)
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# ...

# %% [markdown]
# ## **2020**

# %%
# Filter rows where the 'Year' column is equal to 2020
df1_2020 = df[df['Year'] == 2020]

# Convert float values to strings
df1_2020['Review'] = df1_2020['Review'].astype(str)

# Tokenize documents
documents = [comment.split() for comment in df1_2020["Review"]]

# Create dictionary and corpus
vocab = corpora.Dictionary(documents)
corpus = [vocab.doc2bow(text) for text in documents]

# Set hyperparameters
alpha = 0.1  # Hyperparameter for document-topic distribution
eta = 0.01    # Hyperparameter for topic-word distribution, determined automatically by Gensim

# Define a range of topic numbers to explore
topic_range = range(5, 31)

def compute_coherence(documents, vocab, corpus, topic_range):
    coherence_scores = []
    for num_topics in topic_range:
        lda = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                              id2word=vocab,
                                              num_topics=num_topics,
                                              alpha=alpha,
                                              eta=eta,
                                              random_state=42)  # Choose any desired seed value

        coherence_model = CoherenceModel(model=lda, texts=documents, dictionary=vocab, coherence='c_v')
        coherence = coherence_model.get_coherence()
        coherence_scores.append(coherence)

    return coherence_scores

# Call the function and store the results
coherence_scores = compute_coherence(documents, vocab, corpus, topic_range)

# Plotting coherence scores
plt.figure(figsize=(10, 5))
plt.plot(topic_range, coherence_scores, marker='o')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score")
plt.title("Coherence Score vs. Number of Topics(2020)")

# Set the x-axis ticks explicitly to show all numbers
plt.xticks(list(topic_range))

plt.show()
# Out:
# <ipython-input-7-9a8a4a86a6fd>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2020['Review'] = df1_2020['Review'].astype(str)
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# ...

# %% [markdown]
# ## 2021

# %%
# Filter rows where the 'Year' column is equal to 2021
df1_2021 = df[df['Year'] == 2021]

# Convert float values to strings
df1_2021['Review'] = df1_2021['Review'].astype(str)

# Tokenize documents
documents = [comment.split() for comment in df1_2021["Review"]]

# Create dictionary and corpus
vocab = corpora.Dictionary(documents)
corpus = [vocab.doc2bow(text) for text in documents]

# Set hyperparameters
alpha = 0.1  # Hyperparameter for document-topic distribution
eta = 0.01    # Hyperparameter for topic-word distribution, determined automatically by Gensim

# Define a range of topic numbers to explore
topic_range = range(5, 31)

def compute_coherence(documents, vocab, corpus, topic_range):
    coherence_scores = []
    for num_topics in topic_range:
        lda = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                              id2word=vocab,
                                              num_topics=num_topics,
                                              alpha=alpha,
                                              eta=eta,
                                              random_state=42)  # Choose any desired seed value

        coherence_model = CoherenceModel(model=lda, texts=documents, dictionary=vocab, coherence='c_v')
        coherence = coherence_model.get_coherence()
        coherence_scores.append(coherence)

    return coherence_scores

# Call the function and store the results
coherence_scores = compute_coherence(documents, vocab, corpus, topic_range)

# Plotting coherence scores
plt.figure(figsize=(10, 5))
plt.plot(topic_range, coherence_scores, marker='o')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score")
plt.title("Coherence Score vs. Number of Topics (2021)")

# Set the x-axis ticks explicitly to show all numbers
plt.xticks(list(topic_range))

plt.show()
# Out:
# <ipython-input-8-884bc1014452>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2021['Review'] = df1_2021['Review'].astype(str)
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# ...

# %% [markdown]
# ## 2022

# %%
# Filter rows where the 'Year' column is equal to 2022
df1_2022 = df[df['Year'] == 2022]

# Convert float values to strings
df1_2022['Review'] = df1_2022['Review'].astype(str)

# Tokenize documents
documents = [comment.split() for comment in df1_2022["Review"]]

# Create dictionary and corpus
vocab = corpora.Dictionary(documents)
corpus = [vocab.doc2bow(text) for text in documents]

# Set hyperparameters
alpha = 0.1  # Hyperparameter for document-topic distribution
eta = 0.01    # Hyperparameter for topic-word distribution, determined automatically by Gensim

# Define a range of topic numbers to explore
topic_range = range(5, 31)

def compute_coherence(documents, vocab, corpus, topic_range):
    coherence_scores = []
    for num_topics in topic_range:
        lda = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                              id2word=vocab,
                                              num_topics=num_topics,
                                              alpha=alpha,
                                              eta=eta,
                                              random_state=42)  # Choose any desired seed value

        coherence_model = CoherenceModel(model=lda, texts=documents, dictionary=vocab, coherence='c_v')
        coherence = coherence_model.get_coherence()
        coherence_scores.append(coherence)

    return coherence_scores

# Call the function and store the results
coherence_scores = compute_coherence(documents, vocab, corpus, topic_range)

# Plotting coherence scores
plt.figure(figsize=(10, 5))
plt.plot(topic_range, coherence_scores, marker='o')
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score")
plt.title("Coherence Score vs. Number of Topics(2022)")

# Set the x-axis ticks explicitly to show all numbers
plt.xticks(list(topic_range))

plt.show()
# Out:
# <ipython-input-9-5242a7f61724>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2022['Review'] = df1_2022['Review'].astype(str)
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# ...
